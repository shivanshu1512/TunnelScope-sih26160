# %%
import onnx

traffic_onnx = onnx.load("../models/traffic_classifier.onnx")
security_onnx = onnx.load("../models/security_classifier.onnx")
risk_onnx = onnx.load("../models/risk_regressor.onnx")

onnx.checker.check_model(traffic_onnx)
onnx.checker.check_model(security_onnx)
onnx.checker.check_model(risk_onnx)

print("All ONNX models are valid.")
# Out:
# All ONNX models are valid.
